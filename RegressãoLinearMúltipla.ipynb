# %% [markdown]
# <a href="https://colab.research.google.com/github/felipelimapy/Study-on-Machine-Learning/blob/main/Regress%C3%A3oLinearM%C3%BAltipla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
df=pd.read_csv("/content/insurance.csv", delimiter=';')

# %%
df
# Out:
#       age     bmi  children     region      charges
# 0      19  27.900         0  southwest  16884.92400
# 1      18  33.770         1  southeast   1725.55230
# 2      28  33.000         3  southeast   4449.46200
# 3      33  22.705         0  northwest  21984.47061
# 4      32  28.880         0  northwest   3866.85520
# ...   ...     ...       ...        ...          ...
# 1333   50  30.970         3  northwest  10600.54830
# 1334   18  31.920         0  northeast   2205.98080
# 1335   18  36.850         0  southeast   1629.83350
# 1336   21  25.800         0  southwest   2007.94500
# 1337   61  29.070         0  northwest  29141.36030
#
# [1338 rows x 5 columns]

# %%
x=df.iloc[:,:-1].values
y= df.iloc[:,-1].values

# %%
x
# Out:
# array([[19, 27.9, 0, 'southwest'],
#        [18, 33.77, 1, 'southeast'],
#        [28, 33.0, 3, 'southeast'],
#        ...,
#        [18, 36.85, 0, 'southeast'],
#        [21, 25.8, 0, 'southwest'],
#        [61, 29.07, 0, 'northwest']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder_X = LabelEncoder() #transformando letras em números binários

# %%
x[:, 3] = labelencoder_X.fit_transform(x[:, 3]) #atribundo o valor binário a coluna 3 (região)

# %%
d=pd.get_dummies(x[:,3]).values

# %%
x = x[:,:3]

# %%
for j in range(0, d.shape[1]):
  x = np.insert(x, 3, d[:,j], axis=1)

# %%
x = x[:,:-1]

# %%
from sklearn.model_selection import train_test_split

# %%
xTrain, xTest, yTrain, yTest= train_test_split(x,y, test_size=0.2)

# %%
print (len(xTrain), len(xTest))
# Out:
# 1070 268

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor= LinearRegression()

# %%
regressor.fit(xTrain, yTrain)
# Out:
# LinearRegression()

# %%
yPred=regressor.predict(xTest)

# %%
#mostrando o diferença entre o que é do dadaset e o que o modelo aprendeu
#verificando a quantidade de erro
for i in range(0, yTest.shape[0]) :
  print (yPred[i], yTest[i], abs(yPred[i]-yTest[i])) #yPred é o que o modelo disse e yTest é o que está na base
# Out:
# 25172.58675411934 12592.5345 12580.05225411934
# 19809.875913188655 10736.87075 9073.005163188654
# 3714.916821954772 20167.33603 16452.419208045227
# 13987.478598335587 23967.38305 9979.904451664414
# 17015.08473383061 6666.243 10348.841733830608
# 15191.389498237786 8606.2174 6585.1720982377865
# 6866.528984509896 18033.9679 11167.438915490104
# 14434.689776269468 8551.347 5883.342776269468
# 8865.625992391464 35147.52848 26281.90248760854
# 22337.893373709725 36580.28216 14242.388786290277
# 20430.756240344694 10579.711 9851.045240344694
# 10709.023382168274 2899.48935 7809.534032168274
# 9212.613369858296 4428.88785 4783.725519858296
# 14536.08997972454 12094.478 2441.611979724541
# 11188.075626678848 34806.4677 23618.392073321153
# 13758.653829946565 24393.6224 10634.968570053436
# 18098.441012604722 20781.48892 2683.0479073952774
# 5734.139066986278 1253.936 4480.203066986278
# 11047.072854298254 3972.9247 7074.148154298255
# 6434.809548665746 33307.5508 26872.74125133425
# ...

# %%
prev= regressor.predict(xTest)

from sklearn import metrics
print ("RMSE", np.sqrt (metrics.mean_squared_error(yTest, prev))) #avaliando o erro médio da regressão
# Out:
# RMSE 11452.384531000509

# %% [markdown]
# BACKWARDSELIMITATION

# %%
import statsmodels.api as sm

# %%
x= np.insert(x,0, 1, axis=1) #INSERINDO UMA COLUNA NA POSIÇÃO 0 COM VALORES 1

# %%
x
# Out:
# array([[1, 19, 27.9, ..., 1, 0, 0],
#        [1, 18, 33.77, ..., 0, 1, 0],
#        [1, 28, 33.0, ..., 0, 1, 0],
#        ...,
#        [1, 18, 36.85, ..., 0, 1, 0],
#        [1, 21, 25.8, ..., 1, 0, 0],
#        [1, 61, 29.07, ..., 0, 0, 1]], dtype=object)

# %%
xO= x[:,[0,1,2,3,4,5,6]]

# %%
xO=xO.astype(float)

# %%
regress= sm.OLS(y, xO).fit()

# %%
print (regress.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.123
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     31.26
# Date:                Tue, 29 Nov 2022   Prob (F-statistic):           2.77e-35
# Time:                        04:01:11   Log-Likelihood:                -14389.
# No. Observations:                1338   AIC:                         2.879e+04
# Df Residuals:                    1331   BIC:                         2.883e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5978.2665   1824.861     -3.276      0.001   -9558.184   -2398.349
# ...
